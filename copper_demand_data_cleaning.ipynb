# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("resources/copper_demand.csv")
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2 Stated Policies scenario Unnamed: 4  \
# 0        NaN       2023         NaN                     2030       2035
# 1        NaN        NaN         NaN                      NaN        NaN
# 2     Copper        NaN         NaN                      NaN        NaN
# 3   Solar PV       1208         NaN                     1691       1728
# 4       Wind        502         NaN                      804        692
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Announced Pledges scenario  \
# 0       2040       2045       2050         NaN                       2030
# 1        NaN        NaN        NaN         NaN                        NaN
# 2        NaN        NaN        NaN         NaN                        NaN
# 3       1684       1773       1959         NaN                       2117
# 4        580        626        805         NaN                       1052
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# 0        2035        2040        2045        2050          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN
# 3        2168        2049        1984        2401          NaN
# 4         968         939        1047        1297          NaN
#
#   Net Zero Emissions by 2050 scenario Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0                                2030        2035        2040        2045
# 1                                 NaN         NaN         NaN         NaN
# 2                                 NaN         NaN         NaN         NaN
# 3                                2564        2651        2245        1841
# 4                                1419        1445        1243        1108
#
#   Unnamed: 19
# 0        2050
# 1         NaN
# 2         NaN
# 3        2390
# 4        1451

# %%
data.columns = data.iloc[0]
data = data[1:]

# %%
df_transposed = data.transpose()
df_transposed.head()
# Out:
#        1       2         3     4                                     5   \
# 0
# NaN   NaN  Copper  Solar PV  Wind  Other low emissions power generation
# 2023  NaN     NaN      1208   502                                    83
# NaN   NaN     NaN       NaN   NaN                                   NaN
# 2030  NaN     NaN      1691   804                                   123
# 2035  NaN     NaN      1728   692                                    81
#
#                      6                     7                     8   \
# 0
# NaN   Electric vehicles  Grid battery storage  Electricity networks
# 2023                396                    40                  4143
# NaN                 NaN                   NaN                   NaN
# 2030               1645                   176                  6104
# 2035               2594                   260                  6168
#
#                          9                         10          11  \
# 0
# NaN   Hydrogen technologies  Total clean technologies  Other uses
# 2023                      0                      6372       19543
# NaN                     NaN                       NaN         NaN
# 2030                      0                     10542       20341
# 2035                      0                     11523       21038
#
#                 12                                            13
# 0
# NaN   Total demand  Share of clean technologies in total demand
# 2023         25915                                           25%
# NaN            NaN                                           NaN
# 2030         30883                                           34%
# 2035         32561                                           35%

# %%
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed[1:]
df_transposed.head()
# Out:
# nan   NaN Copper Solar PV Wind Other low emissions power generation  \
# 0
# 2023  NaN    NaN     1208  502                                   83
# NaN   NaN    NaN      NaN  NaN                                  NaN
# 2030  NaN    NaN     1691  804                                  123
# 2035  NaN    NaN     1728  692                                   81
# 2040  NaN    NaN     1684  580                                   83
#
# nan  Electric vehicles Grid battery storage Electricity networks  \
# 0
# 2023               396                   40                 4143
# NaN                NaN                  NaN                  NaN
# 2030              1645                  176                 6104
# 2035              2594                  260                 6168
# 2040              3131                  381                 6125
#
# nan  Hydrogen technologies Total clean technologies Other uses Total demand  \
# 0
# 2023                     0                     6372      19543        25915
# NaN                    NaN                      NaN        NaN          NaN
# 2030                     0                    10542      20341        30883
# 2035                     0                    11523      21038        32561
# 2040                     0                    11984      21997        33981
#
# nan  Share of clean technologies in total demand
# 0
# 2023                                          25%
# NaN                                           NaN
# 2030                                          34%
# 2035                                          35%
# 2040                                          35%

# %%
df_cleaned = df_transposed.dropna(how='all').dropna(axis=1, how='all')
df_cleaned.head()
# Out:
# nan  Solar PV Wind Other low emissions power generation Electric vehicles  \
# 0
# 2023     1208  502                                   83               396
# 2030     1691  804                                  123              1645
# 2035     1728  692                                   81              2594
# 2040     1684  580                                   83              3131
# 2045     1773  626                                  108              3287
#
# nan  Grid battery storage Electricity networks Hydrogen technologies  \
# 0
# 2023                   40                 4143                     0
# 2030                  176                 6104                     0
# 2035                  260                 6168                     0
# 2040                  381                 6125                     0
# 2045                  454                 6312                     0
#
# nan  Total clean technologies Other uses Total demand  \
# 0
# 2023                     6372      19543        25915
# 2030                    10542      20341        30883
# 2035                    11523      21038        32561
# 2040                    11984      21997        33981
# 2045                    12560      23564        36124
#
# nan  Share of clean technologies in total demand
# 0
# 2023                                          25%
# 2030                                          34%
# 2035                                          35%
# 2040                                          35%
# 2045                                          35%

# %%
scenarios = np.repeat(['STEPS', 'APS', 'NZE'],(len(df_cleaned)/ 3))
scenarios = np.insert(scenarios, 0, "BASE")

df_new = df_cleaned.assign(scenarios=scenarios)
df_new.head()
# Out:
# nan  Solar PV Wind Other low emissions power generation Electric vehicles  \
# 0
# 2023     1208  502                                   83               396
# 2030     1691  804                                  123              1645
# 2035     1728  692                                   81              2594
# 2040     1684  580                                   83              3131
# 2045     1773  626                                  108              3287
#
# nan  Grid battery storage Electricity networks Hydrogen technologies  \
# 0
# 2023                   40                 4143                     0
# 2030                  176                 6104                     0
# 2035                  260                 6168                     0
# 2040                  381                 6125                     0
# 2045                  454                 6312                     0
#
# nan  Total clean technologies Other uses Total demand  \
# 0
# 2023                     6372      19543        25915
# 2030                    10542      20341        30883
# 2035                    11523      21038        32561
# 2040                    11984      21997        33981
# 2045                    12560      23564        36124
#
# nan  Share of clean technologies in total demand  scenarios
# 0
# 2023                                          25%      BASE
# 2030                                          34%     STEPS
# 2035                                          35%     STEPS
# 2040                                          35%     STEPS
# 2045                                          35%     STEPS

# %%
df_new['Critical Minerals'] = "Copper"
df_new.head()
# Out:
# nan  Solar PV Wind Other low emissions power generation Electric vehicles  \
# 0
# 2023     1208  502                                   83               396
# 2030     1691  804                                  123              1645
# 2035     1728  692                                   81              2594
# 2040     1684  580                                   83              3131
# 2045     1773  626                                  108              3287
#
# nan  Grid battery storage Electricity networks Hydrogen technologies  \
# 0
# 2023                   40                 4143                     0
# 2030                  176                 6104                     0
# 2035                  260                 6168                     0
# 2040                  381                 6125                     0
# 2045                  454                 6312                     0
#
# nan  Total clean technologies Other uses Total demand  \
# 0
# 2023                     6372      19543        25915
# 2030                    10542      20341        30883
# 2035                    11523      21038        32561
# 2040                    11984      21997        33981
# 2045                    12560      23564        36124
#
# nan  Share of clean technologies in total demand  scenarios Critical Minerals
# 0
# 2023                                          25%      BASE            Copper
# 2030                                          34%     STEPS            Copper
# 2035                                          35%     STEPS            Copper
# 2040                                          35%     STEPS            Copper
# 2045                                          35%     STEPS            Copper

# %%
df_new.reset_index(drop=False, inplace=True)
df_new.head()
# Out:
# nan     0 Solar PV Wind Other low emissions power generation  \
# 0    2023     1208  502                                   83
# 1    2030     1691  804                                  123
# 2    2035     1728  692                                   81
# 3    2040     1684  580                                   83
# 4    2045     1773  626                                  108
#
# nan Electric vehicles Grid battery storage Electricity networks  \
# 0                 396                   40                 4143
# 1                1645                  176                 6104
# 2                2594                  260                 6168
# 3                3131                  381                 6125
# 4                3287                  454                 6312
#
# nan Hydrogen technologies Total clean technologies Other uses Total demand  \
# 0                       0                     6372      19543        25915
# 1                       0                    10542      20341        30883
# 2                       0                    11523      21038        32561
# 3                       0                    11984      21997        33981
# 4                       0                    12560      23564        36124
#
# nan Share of clean technologies in total demand  scenarios Critical Minerals
# 0                                            25%      BASE            Copper
# 1                                            34%     STEPS            Copper
# 2                                            35%     STEPS            Copper
# 3                                            35%     STEPS            Copper
# 4                                            35%     STEPS            Copper

# %%
df_new.rename(columns={0: 'Year'}, inplace=True)
df_new.head()
# Out:
# nan  Year Solar PV Wind Other low emissions power generation  \
# 0    2023     1208  502                                   83
# 1    2030     1691  804                                  123
# 2    2035     1728  692                                   81
# 3    2040     1684  580                                   83
# 4    2045     1773  626                                  108
#
# nan Electric vehicles Grid battery storage Electricity networks  \
# 0                 396                   40                 4143
# 1                1645                  176                 6104
# 2                2594                  260                 6168
# 3                3131                  381                 6125
# 4                3287                  454                 6312
#
# nan Hydrogen technologies Total clean technologies Other uses Total demand  \
# 0                       0                     6372      19543        25915
# 1                       0                    10542      20341        30883
# 2                       0                    11523      21038        32561
# 3                       0                    11984      21997        33981
# 4                       0                    12560      23564        36124
#
# nan Share of clean technologies in total demand  scenarios Critical Minerals
# 0                                            25%      BASE            Copper
# 1                                            34%     STEPS            Copper
# 2                                            35%     STEPS            Copper
# 3                                            35%     STEPS            Copper
# 4                                            35%     STEPS            Copper

# %%
df_new.to_excel("outputs/copper_demand.xlsx", index=False)
